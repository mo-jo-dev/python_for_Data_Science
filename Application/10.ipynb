# %%
# Integer - 1

# %%
# Floating point number - 1.0

# %% [markdown]
# Arithmetic Operations

# %%
1 + 1
# Out:
# 2

# %%
1 * 3
# Out:
# 3

# %%
1 / 2
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
2 + 3 * 5 + 5
# Out:
# 22

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %%
4 % 2
# Out:
# 0

# %% [markdown]
# Variable Assignment
# - Can't start with numbers
# - Can't start with special symbols

# %%
var = 2
var
# Out:
# 2

# %%
x = 2
y = 5

# %%
x + y
# Out:
# 7

# %%
x = x + x
x
# Out:
# 4

# %% [markdown]
# String Datatype
# - Using both single and double quotes

# %%
s = "Hello!"
s
# Out:
# 'Hello!'

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
" wrap lot's of other quotes"
# Out:
# " wrap lot's of other quotes"

# %%
print(s)
# Out:
# Hello!

# %%
# Formating being done by three methods
    # One using .format function and
    # Another using f"" and
    # Using placeholders to prevent any problem with arrangement of variables

# %%
num = 12
name = "mojo"

# %%
print('My number is {} and my name is {}.'.format(num, name))
# Out:
# My number is 12 and my name is mojo.

# %%
print(f"My number is {num} and my name is {name}.")
# Out:
# My number is 12 and my name is mojo.

# %%
print('My number is {one} and my name is {two}.'.format(two = name, one = num))
# Out:
# My number is 12 and my name is mojo.

# %%
# Indexing
st = "abcdefghijklmnopqrstuvwxyz"
st[0]
# Out:
# 'a'

# %%
st[1]
# Out:
# 'b'

# %%
st[0:26]    #Slice notation
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
st[0:]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
st[:12]
# Out:
# 'abcdefghijkl'

# %%
st[0:26:5]   #[Start, End, Stride]
# Out:
# 'afkpuz'

# %% [markdown]
# Lists - Are a sequence of elements in a square bracket seperated by commas

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
['a', 'b', 'c']
# Out:
# ['a', 'b', 'c']

# %%
my_list = ['a', 'b', 'c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[1:3]
# Out:
# ['b', 'c']

# %%
my_list[0] = 'updated_a'
my_list
# Out:
# ['updated_a', 'b', 'c', 'd']

# %%
nest = [1, 2, 3, [1, 2, 3, 'mohit']]

# %%
nest
# Out:
# [1, 2, 3, [1, 2, 3, 'mohit']]

# %%
nest = [1, 2, 3, [4, 5, ['mohit']]]

# %%
nest[3:]
# Out:
# [[4, 5, ['mohit']]]

# %%
nest[3][2]
# Out:
# ['mohit']

# %%
nest[3][2][0]
# Out:
# 'mohit'

# %%
print(nest[3][2][0])
# Out:
# mohit
